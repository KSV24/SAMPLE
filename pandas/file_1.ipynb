# %%
import pandas as pd
list = pd.Series([10,20,30])
print(list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import numpy as np
import pandas as pd

def generate_school_data(students=100, seed=42):
    np.random.seed(seed)
    
    data = {
        "Math": np.random.randint(35, 100, students),
        "Science": np.random.randint(35, 100, students),
        "English": np.random.randint(35, 100, students),
        "Attendance (%)": np.random.randint(60, 100, students),
        "Study Hours (per week)": np.random.randint(1, 20, students)
    }
    df = pd.DataFrame(data)
    return df
school_df = generate_school_data(10)
print("School Dataset:\n")
print(school_df)
print("\nShape:", school_df.shape)
# Out:
# School Dataset:
#
#    Math  Science  English  Attendance (%)  Study Hours (per week)
# 0    86       72       76              62                      18
# 1    49       36       94              96                       9
# 2    95       98       49              66                       2
# 3    55       94       96              80                      15
# 4    58       55       96              68                       7
# 5    37       67       81              98                      12
# 6    56       92       96              77                       8
# 7    87       56       85              63                      15
# 8    36       83       89              84                       3
# 9    64       93       98              73                      14
#
# Shape: (10, 5)
