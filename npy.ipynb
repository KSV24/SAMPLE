# %%
import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
import numpy as np
arr = np.array([[1,2],[3,4]])
print(arr)
print(type(arr))
# Out:
# [[1 2]
#  [3 4]]
# <class 'numpy.ndarray'>

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a+10)
# Out:
# [11 12 13 14]

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([3,4,5])
print(np.dot(a,b))
# Out:
# 26

# %%
import numpy as np
a=np.array([[1,2],
            [3,4],[5,6]])
print(a.T)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
import numpy as np
a=np.array([[1,2,3],
            [3,4,6],
            [3,4,5]])
print(np.linalg.norm(a))
# Out:
# 11.180339887498949
